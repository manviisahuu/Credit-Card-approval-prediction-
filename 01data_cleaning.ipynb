# %%
import pandas as pd
#loading dataset
df = pd.read_csv("C:/Users/DELL/Documents/Credit card approval project/application_record.csv")
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
print("Dataset Loaded — Shape:", df.shape)
# Out:
# Dataset Loaded — Shape: (438557, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
print(df.describe(include='all'))
# Out:
#                   ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY   CNT_CHILDREN  \
# count   4.385570e+05      438557       438557          438557  438557.000000
# unique           NaN           2            2               2            NaN
# top              NaN           F            N               Y            NaN
# freq             NaN      294440       275459          304074            NaN
# mean    6.022176e+06         NaN          NaN             NaN       0.427390
# std     5.716370e+05         NaN          NaN             NaN       0.724882
# min     5.008804e+06         NaN          NaN             NaN       0.000000
# 25%     5.609375e+06         NaN          NaN             NaN       0.000000
# 50%     6.047745e+06         NaN          NaN             NaN       0.000000
# 75%     6.456971e+06         NaN          NaN             NaN       1.000000
# max     7.999952e+06         NaN          NaN             NaN      19.000000
#
# ...

# %%
print(df.isnull().sum())
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
df['days_birth'] = abs(df['days_birth'])
df['days_employed'] = abs(df['days_employed'])

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
df['occupation_type'] = df['occupation_type'].fillna('Unknown')

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
df['age'] = (df['days_birth'] / 365).astype(int)

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
df['approved'] = (
    (df['amt_income_total'] > 150000) &
    (df['age'] < 60) &
    (df['cnt_children'] <= 2)
).astype(int)

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
print(" Target column 'approved' created (1 = likely approved, 0 = not).")
# Out:
#  Target column 'approved' created (1 = likely approved, 0 = not).

# %%
print("\n Target Distribution:")
print(df['approved'].value_counts())
# Out:
#  Target Distribution:
# approved
# 1    237411
# 0    201146
# Name: count, dtype: int64

# %%
df.to_csv("processed_credit.csv", index=False)
print("\n Cleaned dataset saved as 'processed_credit.csv'")
# Out:
# 💾 Cleaned dataset saved as 'processed_credit.csv'
