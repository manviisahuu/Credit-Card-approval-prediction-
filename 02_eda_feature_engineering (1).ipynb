# %% [markdown]
# # **EDA**

# %%
import pandas as pd
df = pd.read_csv("C:/Users/DELL/Documents/Credit card approval project/processed_credit_cleaned.csv")

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  days_birth  days_employed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   438557 non-null  int64
#  1   code_gender          438557 non-null  object
#  2   flag_own_car         438557 non-null  object
#  3   flag_own_realty      438557 non-null  object
#  4   cnt_children         438557 non-null  int64
#  5   amt_income_total     438557 non-null  float64
#  6   name_income_type     438557 non-null  object
#  7   name_education_type  438557 non-null  object
#  8   name_family_status   438557 non-null  object
#  9   name_housing_type    438557 non-null  object
#  10  days_birth           438557 non-null  int64
#  11  days_employed        438557 non-null  int64
#  12  flag_mobil           438557 non-null  int64
#  13  flag_work_phone      438557 non-null  int64
#  14  flag_phone           438557 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id   cnt_children  amt_income_total     days_birth  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05   15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04    7489.000000
# 25%    5.609375e+06       0.000000      1.215000e+05   12514.000000
# 50%    6.047745e+06       0.000000      1.607805e+05   15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05   19483.000000
# max    7.999952e+06      19.000000      6.750000e+06   25201.000000
#
#        days_employed  flag_mobil  flag_work_phone     flag_phone  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    64908.680361         1.0         0.206133       0.287771
# std    136789.337884         0.0         0.404527       0.452724
# min        12.000000         1.0         0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (438557, 20)

# %%
df.columns
# Out:
# Index(['id', 'code_gender', 'flag_own_car', 'flag_own_realty', 'cnt_children',
#        'amt_income_total', 'name_income_type', 'name_education_type',
#        'name_family_status', 'name_housing_type', 'days_birth',
#        'days_employed', 'flag_mobil', 'flag_work_phone', 'flag_phone',
#        'flag_email', 'occupation_type', 'cnt_fam_members', 'age', 'approved'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                     0
# code_gender            0
# flag_own_car           0
# flag_own_realty        0
# cnt_children           0
# amt_income_total       0
# name_income_type       0
# name_education_type    0
# name_family_status     0
# name_housing_type      0
# days_birth             0
# days_employed          0
# flag_mobil             0
# flag_work_phone        0
# flag_phone             0
# flag_email             0
# occupation_type        0
# cnt_fam_members        0
# age                    0
# approved               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.histplot(df['amt_income_total'], bins=50, kde=True, color='skyblue')
plt.xlim(0, 500000)  # Zoom only to 0–5 lakh
plt.title('Income Distribution (Zoomed)')
plt.xlabel('Income Amount')
plt.ylabel('Number of Applicants')
plt.grid(True)
plt.show()
#here the income range is zoomed and outliers are removed like if someone is aving value more than normal income they are not counted here.

# %%
import numpy as np

plt.figure(figsize=(8, 5))
sns.histplot(np.log1p(df['amt_income_total']), bins=50, kde=True, color='salmon')
plt.title('Log Transformed Income Distribution')
plt.xlabel('Log(Income Amount)')
plt.ylabel('Number of Applicants')
plt.grid(True)
plt.show()

#n this dataset, people don’t earn continuous income like ₹1,00,000, ₹1,00,001, ₹1,00,002 etc.Income is grouped at specific levels — like ₹2 lakh, ₹5 lakh, ₹10 lakh, ₹15 lakh, etc.
#That’s why in histogram, when you log-transform and plot: Some bins (small income ranges) have more people → high bars (peaks). Some bins have fewer people → small bars (drops).
#When we take log(income), low income values (say ₹100, ₹1000, ₹10,000) become even lower spaced numbers like 2, 3, 4 that is why plot is falling down and in last values like 2 million etc very less people are there with these values so value is falling down again

# %%
# Convert to Age

plt.figure(figsize=(8, 5))
sns.histplot(df['age'], bins=50, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='cnt_children', data=df, palette='viridis')
plt.title('Number of Children Distribution')
plt.xlabel('Number of Children')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\1197448249.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cnt_children', data=df, palette='viridis')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='name_income_type', data=df, palette='Set2')
plt.title('Income Type Distribution')
plt.xlabel('Income Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\2834377711.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='name_income_type', data=df, palette='Set2')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='name_education_type', data=df, palette='coolwarm')
plt.title('Education Type Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\2748031165.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='name_education_type', data=df, palette='coolwarm')

# %% [raw]
# Feature Name	          Missing Values?	Outliers Present?	 Skewed?	     Action Plan
# AMT_INCOME_TOTAL	          No	            Yes	               Yes	    Log Transform, Handle outliers
# AGE                        	  No	            maybe        	    No	    Binning, Handle outliers
# CNT_CHILDREN	              No	            Yes	                No	    Cap maximum children
# NAME_INCOME_TYPE           	  No            	 No              	No	        Encoding
# NAME_EDUCATION_TYPE	          No	             No             	No      	Encoding

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot for numerical feature vs target
sns.barplot(x='approved', y='amt_income_total', data=df)
plt.title('Income vs Approval Status')
plt.show()

# %%
# Countplot for categorical feature vs target
sns.countplot(x='code_gender', hue='approved', data=df)
plt.title('Gender vs Approval Status')
plt.show()

# %%
# Simple missing value check
print(df.isnull().sum())
# Out:
# id                     0
# code_gender            0
# flag_own_car           0
# flag_own_realty        0
# cnt_children           0
# amt_income_total       0
# name_income_type       0
# name_education_type    0
# name_family_status     0
# name_housing_type      0
# days_birth             0
# days_employed          0
# flag_mobil             0
# flag_work_phone        0
# flag_phone             0
# flag_email             0
# occupation_type        0
# cnt_fam_members        0
# age                    0
# approved               0
# dtype: int64

# %%
# Visual check
sns.boxplot(x=df['amt_income_total'])
plt.title('Income Boxplot')
plt.show()

# Numeric check
Q1 = df['amt_income_total'].quantile(0.25)
Q3 = df['amt_income_total'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower}, Upper Bound: {upper}")

outliers = df[(df['amt_income_total'] < lower) | (df['amt_income_total'] > upper)]
print(f"Number of outliers: {outliers.shape[0]}")
# Out:
# Lower Bound: -33750.0, Upper Bound: 380250.0
# Number of outliers: 19108

# %%
# Check skewness value
print(df['amt_income_total'].skew())

# Thumb rule:
# Skewness > 0.5 = Moderate Positive Skew
# Skewness < -0.5 = Moderate Negative Skew
# Skewness between -0.5 and 0.5 = Normal
# Out:
# 8.834065744752545

# %%
import numpy as np
df['amt_income_total_log'] = np.log1p(df['amt_income_total'])

# %%
# Create a boxplot to see income distribution by gender and approval
plt.figure(figsize=(10,6))
sns.barplot(x='code_gender', y='amt_income_total', hue='approved', data=df)
plt.title('Income Distribution by Gender and Approval Status')
plt.ylabel('Income')
plt.xlabel('Gender')
plt.legend(title='Approved')
plt.show()

# %%
# Select only numeric columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
print(num_cols)
# Out:
# Index(['id', 'cnt_children', 'amt_income_total', 'days_birth', 'days_employed',
#        'flag_mobil', 'flag_work_phone', 'flag_phone', 'flag_email',
#        'cnt_fam_members', 'age', 'approved', 'amt_income_total_log'],
#       dtype='object')

# %%
for col in num_cols:
    print(f'{col}: {df[col].skew()}')
# Out:
# id: 0.21271759012353048
# cnt_children: 1.8069407093611092
# amt_income_total: 8.834065744752545
# days_birth: 0.16018090508137486
# days_employed: 1.7394817629197503
# flag_mobil: 0.0
# flag_work_phone: 1.4528976613203697
# flag_phone: 0.9375680348113513
# flag_email: 2.5224817629771326
# cnt_fam_members: 0.919676246825922
# age: 0.16075761049319215
# approved: -0.16595221303727867
# amt_income_total_log: 0.1558642386721578

# %%
def check_outliers(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    print(f"Column: {col}")
    print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
    print(f"Number of outliers: {outliers.shape[0]}")
    print("-"*50)

# Now apply this function to every numeric column:
for col in num_cols:
    check_outliers(col)
# Out:
# Column: id
# Lower Bound: 4337981.0, Upper Bound: 7728365.0
# Number of outliers: 3243
# --------------------------------------------------
# Column: cnt_children
# Lower Bound: -1.5, Upper Bound: 2.5
# Number of outliers: 6075
# --------------------------------------------------
# Column: amt_income_total
# Lower Bound: -33750.0, Upper Bound: 380250.0
# Number of outliers: 19108
# --------------------------------------------------
# Column: days_birth
# Lower Bound: 2060.5, Upper Bound: 29936.5
# Number of outliers: 0
# --------------------------------------------------
# Column: days_employed
# Lower Bound: -6041.0, Upper Bound: 12983.0
# Number of outliers: 76528
# --------------------------------------------------
# Column: flag_mobil
# Lower Bound: 1.0, Upper Bound: 1.0
# Number of outliers: 0
# --------------------------------------------------
# Column: flag_work_phone
# Lower Bound: 0.0, Upper Bound: 0.0
# Number of outliers: 90401
# ...

# %%
df.head()
# Out:
#         id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    amt_income_total      name_income_type            name_education_type  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      name_family_status  name_housing_type  ...  days_employed  flag_mobil  \
# ...

# %%
# Cap days_employed between -5000 and 5000
df['days_employed'] = df['days_employed'].clip(lower=-5000, upper=5000)

# %%
# 2. Income vs Approval (Using Log Income)
plt.figure(figsize=(8,6))
sns.barplot(data=df, x='approved', y='amt_income_total_log', palette='Set3')
plt.title('Income (Log Transformed) vs Approval')
plt.xlabel('Approved')
plt.ylabel('Log of Annual Income')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\2394904981.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='approved', y='amt_income_total_log', palette='Set3')

# %%
# 3. Education vs Approval
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='name_education_type', hue='approved', palette='Set1')
plt.title('Approval by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Approved')
plt.show()

# %%
# 4. Marital Status vs Approval
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='name_family_status', hue='approved', palette='coolwarm')
plt.title('Approval by Family Status')
plt.xlabel('Family Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Approved')
plt.show()

# %%
# 5. Occupation vs Approval
plt.figure(figsize=(10,6))
sns.countplot(data=df, y='occupation_type', hue='approved', palette='Spectral')
plt.title('Approval by Occupation Type')
plt.xlabel('Count')
plt.ylabel('Occupation Type')
plt.legend(title='Approved')
plt.show()

# %%
# 6. Age vs Approval
plt.figure(figsize=(8,6))
sns.barplot(data=df, x='approved', y='age', palette='viridis')
plt.title('Age vs Approval')
plt.xlabel('Approved')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\3044977869.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='approved', y='age', palette='viridis')

# %%
# 7. Number of Children vs Approval
plt.figure(figsize=(8,6))
sns.barplot(data=df, x='approved', y='cnt_children', palette='cubehelix')
plt.title('Number of Children vs Approval')
plt.xlabel('Approved')
plt.ylabel('Number of Children')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\332861448.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='approved', y='cnt_children', palette='cubehelix')

# %%
# 8. Employment Days vs Approval
plt.figure(figsize=(8,6))
sns.barplot(data=df, x='approved', y='days_employed', palette='rocket')
plt.title('Employment Duration vs Approval')
plt.xlabel('Approved')
plt.ylabel('Days Employed')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22344\1769303215.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='approved', y='days_employed', palette='rocket')

# %% [markdown]
# # Insights from EDA:
#
# * The majority of users have an annual income between ₹50,000 and ₹3,00,000.
# * Although all age groups are present, most users fall between the ages of 30 to 60 years.
# * Most applicants are currently working and have Secondary or Secondary Special education levels.
# * A large portion of applicants have 0 children, suggesting they might be single or newly married.
# * Loan approvals are more common among applicants earning more than ₹2,00,000 annually.
# * In terms of count, female applicants face higher rejection rates overall, but when compared salary-wise, rejection rates are almost similar between     males and females.
# * However, male applicants have a slightly higher approval rate and a slightly higher rejection rate compared to females.
# * Applicants with Higher Education have a better approval rate, while those with only Secondary education face more rejections (though the number of      secondary-educated applicants is also higher).
# * The number of married applicants is significantly higher, and married applicants also show a relatively higher approval rate. (Possibly because many    are dual earners or stable households with fewer children.)
# * "Laborers" and "Managers" are the two occupation types with the highest number of approved loans.

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
df.columns
# Out:
# Index(['id', 'code_gender', 'flag_own_car', 'flag_own_realty', 'cnt_children',
#        'amt_income_total', 'name_income_type', 'name_education_type',
#        'name_family_status', 'name_housing_type', 'days_birth',
#        'days_employed', 'flag_mobil', 'flag_work_phone', 'flag_phone',
#        'flag_email', 'occupation_type', 'cnt_fam_members', 'age', 'approved',
#        'amt_income_total_log'],
#       dtype='object')

# %%
# Final columns to drop
cols_to_drop = ['id', 'amt_income_total', 'flag_mobil', 'days_birth']

# Dropping the columns
df = df.drop(columns=cols_to_drop)

# Checking remaining columns
print("Remaining columns after dropping:")
print(df.columns)
# Out:
# Remaining columns after dropping:
# Index(['code_gender', 'flag_own_car', 'flag_own_realty', 'cnt_children',
#        'name_income_type', 'name_education_type', 'name_family_status',
#        'name_housing_type', 'days_employed', 'flag_work_phone', 'flag_phone',
#        'flag_email', 'occupation_type', 'cnt_fam_members', 'age', 'approved',
#        'amt_income_total_log'],
#       dtype='object')

# %%
df.head()
# Out:
#   code_gender flag_own_car flag_own_realty  cnt_children  \
# 0           M            Y               Y             0
# 1           M            Y               Y             0
# 2           M            Y               Y             0
# 3           F            N               Y             0
# 4           F            N               Y             0
#
#        name_income_type            name_education_type    name_family_status  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#    name_housing_type  days_employed  flag_work_phone  flag_phone  flag_email  \
# 0   Rented apartment           4542                1           0           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# First Label Encoding (for binary columns)
binary_cols = ['code_gender', 'flag_own_car', 'flag_own_realty']

le = LabelEncoder()
for col in binary_cols:
    df[col] = le.fit_transform(df[col])

# Now One Hot Encoding (for multi-category columns)
multi_cols = ['name_income_type', 'name_education_type', 'name_family_status',
              'name_housing_type', 'occupation_type']

df = pd.get_dummies(df, columns=multi_cols, drop_first=True)

print("Shape after Encoding:", df.shape)
print("Columns after Encoding:")
print(df.columns)
# Out:
# Shape after Encoding: (438557, 47)
# Columns after Encoding:
# Index(['code_gender', 'flag_own_car', 'flag_own_realty', 'cnt_children',
#        'days_employed', 'flag_work_phone', 'flag_phone', 'flag_email',
#        'cnt_fam_members', 'age', 'approved', 'amt_income_total_log',
#        'name_income_type_Pensioner', 'name_income_type_State servant',
#        'name_income_type_Student', 'name_income_type_Working',
#        'name_education_type_Higher education',
#        'name_education_type_Incomplete higher',
#        'name_education_type_Lower secondary',
#        'name_education_type_Secondary / secondary special',
#        'name_family_status_Married', 'name_family_status_Separated',
#        'name_family_status_Single / not married', 'name_family_status_Widow',
#        'name_housing_type_House / apartment',
#        'name_housing_type_Municipal apartment',
#        'name_housing_type_Office apartment',
# ...

# %%
df.head()
# Out:
#    code_gender  flag_own_car  flag_own_realty  cnt_children  days_employed  \
# 0            1             1                1             0           4542
# 1            1             1                1             0           4542
# 2            1             1                1             0           1134
# 3            0             0                1             0           3051
# 4            0             0                1             0           3051
#
#    flag_work_phone  flag_phone  flag_email  cnt_fam_members  age  ...  \
# 0                1           0           0              2.0   32  ...
# 1                1           0           0              2.0   32  ...
# 2                0           0           0              2.0   58  ...
# 3                0           1           1              1.0   52  ...
# 4                0           1           1              1.0   52  ...
#
#    occupation_type_Low-skill Laborers  occupation_type_Managers  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# First select only numeric columns to scale
numeric_cols = ['cnt_children', 'days_employed', 'flag_work_phone',
                'flag_phone', 'flag_email', 'cnt_fam_members', 'age',
                'amt_income_total_log']

scaler = StandardScaler()

# Fit and transform only numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print("Feature Scaling Done!")
# Out:
# Feature Scaling Done!

# %%
df.head()
# Out:
#    code_gender  flag_own_car  flag_own_realty  cnt_children  days_employed  \
# 0            1             1                1       -0.5896       1.004577
# 1            1             1                1       -0.5896       1.004577
# 2            1             1                1       -0.5896      -0.910064
# 3            0             0                1       -0.5896       0.166921
# 4            0             0                1       -0.5896       0.166921
#
#    flag_work_phone  flag_phone  flag_email  cnt_fam_members       age  ...  \
# 0         1.962458   -0.635644   -0.348334        -0.216745 -0.987705  ...
# 1         1.962458   -0.635644   -0.348334        -0.216745 -0.987705  ...
# 2        -0.509565   -0.635644   -0.348334        -0.216745  1.279575  ...
# 3        -0.509565    1.573208    2.870807        -1.331316  0.756357  ...
# 4        -0.509565    1.573208    2.870807        -1.331316  0.756357  ...
#
# ...

# %%
from sklearn.model_selection import train_test_split

# Features and Target
X = df.drop('approved', axis=1)  # Drop the target column
y = df['approved']               # Target column

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,     # 20% test, 80% train
    random_state=42,   # for reproducibility (same split every time)
    stratify=y         # to maintain class balance (important in classification)
)

print("Training Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)
# Out:
# Training Set Shape: (350845, 46)
# Testing Set Shape: (87712, 46)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Initialize Model
lr_model = LogisticRegression(max_iter=1000, random_state=42)

# Train Model
lr_model.fit(X_train, y_train)

# Predict
y_pred_lr = lr_model.predict(X_test)

# Evaluate
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
print("\nClassification Report:\n", classification_report(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.9180841846041591
#
# Confusion Matrix:
#  [[36588  3641]
#  [ 3544 43939]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91     40229
#            1       0.92      0.93      0.92     47483
#
#     accuracy                           0.92     87712
#    macro avg       0.92      0.92      0.92     87712
# weighted avg       0.92      0.92      0.92     87712

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize Model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train Model
rf_model.fit(X_train, y_train)

# Predict
y_pred_rf = rf_model.predict(X_test)

# Evaluate
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 1.0
#
# Confusion Matrix:
#  [[40229     0]
#  [    0 47483]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     40229
#            1       1.00      1.00      1.00     47483
#
#     accuracy                           1.00     87712
#    macro avg       1.00      1.00      1.00     87712
# weighted avg       1.00      1.00      1.00     87712

# %% [markdown]
# #  Business Insights Based on Analysis:
#
# ### Income Impact:
# * Customers with an annual income above 2 lakh are more likely to get their credit applications approved.
#
# ### Age Group Influence:
# * Most users fall between the 30-60 years age group, and this age range has a higher approval rate.
#
# ### Employment Status:
# * People who are working or state servants have a higher approval rate compared to students and pensioners.
#
# ### Education Level:
# * Customers with Higher Education have better approval chances.
# * In contrast, customers with Secondary/Secondary Special education face more rejections.
#
# ### Family and Marital Status:
# * Married customers have a higher approval rate.
# * Especially married customers with no children seem to get loans easily (possibly due to lower financial responsibilities).
#
# ### Gender Analysis:
# * Female customers have higher rejection rates compared to males, although the income levels are somewhat similar across genders.
#
# ### Occupation Impact:
# * People working as Managers and Laborers got a higher number of approvals compared to other professions.
#
# ### Model Comparison:
# * Logistic Regression achieved a good accuracy (~92%), while Random Forest achieved 100% accuracy but may be overfitting.
# * Logistic Regression is more trustworthy for real-world predictions.

# %%
# Feature Importance from Random Forest
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming your Random Forest model is called "rf_model"
# And your feature names are in "X_train.columns"

# Get feature importances
importances = rf_model.feature_importances_
feature_names = X_train.columns

# Create a DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

# Sort by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(12,8))
plt.barh(feature_importance_df['Feature'][:15][::-1], feature_importance_df['Importance'][:15][::-1], color='teal')
plt.xlabel('Feature Importance')
plt.title('Top 15 Important Features (Random Forest)')
plt.grid(True, axis='x')
plt.show()

# Display table
feature_importance_df.head(20)
# Out:
#                                               Feature  Importance
# 10                               amt_income_total_log    0.733130
# 9                                                 age    0.116102
# 11                         name_income_type_Pensioner    0.025158
# 4                                       days_employed    0.021736
# 3                                        cnt_children    0.016335
# 0                                         code_gender    0.013866
# 8                                     cnt_fam_members    0.012874
# 1                                        flag_own_car    0.008235
# 18  name_education_type_Secondary / secondary special    0.006955
# 44                            occupation_type_Unknown    0.006346
# 15               name_education_type_Higher education    0.006198
# 37                           occupation_type_Managers    0.005774
# 14                           name_income_type_Working    0.004494
# ...

# %% [markdown]
# # Feature Importance Analysis (Random Forest)
#
# After training the Random Forest Classifier, we analyzed the top factors affecting Credit Card Approval:
#
# | Rank | Feature | Importance Score |
# |:----:|:--------|:-----------------:|
# | 1 | amt_income_total_log | 0.733130 |
# | 2 | age | 0.116102 |
# | 3 | name_income_type_Pensioner | 0.025158 |
# | 4 | days_employed | 0.021736 |
# | 5 | cnt_children | 0.016335 |
# | 6 | code_gender | 0.013866 |
# | 7 | cnt_fam_members | 0.012874 |
# | 8 | flag_own_car | 0.008235 |
# | 9 | name_education_type_Secondary / secondary special | 0.006955 |
# | 10 | occupation_type_Unknown | 0.006346 |
# | 11 | name_education_type_Higher education | 0.006198 |
# | 12 | occupation_type_Managers | 0.005774 |
# | 13 | name_income_type_Working | 0.004494 |
# | 14 | flag_work_phone | 0.002763 |
# | 15 | flag_email | 0.002445 |
# | 16 | flag_own_realty | 0.001659 |
# | 17 | name_family_status_Married | 0.001525 |
# | 18 | flag_phone | 0.001508 |
# | 19 | name_family_status_Widow | 0.001145 |
# | 20 | name_income_type_State servant | 0.001053 |
#
# ---
#
#  **Key Observations:**
# - `amt_income_total_log` is by far the most important factor affecting credit card approval decisions.
# - `age` of the applicant also plays a significant role, suggesting that younger or middle-aged customers may have better approval chances.
# - Financial stability features such as `name_income_type_Pensioner`, `days_employed`, and `cnt_children` are also critical indicators.
# - Demographic factors like `code_gender` and `cnt_fam_members` contribute moderately to the prediction.
#
# ---
#
# **Business Insight:**
# > Customers with higher total income (`amt_income_total_log`) and an optimal age (`age`) are much more likely to get their credit card applications approved.
# > It is important to target financially stable individuals (like `Pensioners`, `Working` class) and consider employment stability (`days_employed`) while making approval decisions.

# %%
import pickle

# Save the trained Random Forest model
with open('random_forest_model.pkl', 'wb') as file:
    pickle.dump(rf_model, file)

print("Model saved successfully!")
# Out:
# Model saved successfully!
